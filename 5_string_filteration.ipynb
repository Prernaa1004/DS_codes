# %%
import pandas as pd
bios=pd.read_csv("bios.csv")
bios.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg   died_date
# 0               Gironde          FRA  France        NaN        NaN  1960-10-02
# 1              Yvelines          FRA  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0  1994-07-17
# 3                 Paris          FRA  France      168.0       64.0  1978-03-20
# 4               England          GBR  France        NaN        NaN  1930-07-25

# %%
#name starts/ contains 
bios[bios["name"].str.contains("Keith")].head()
# Out:
#        athlete_id           name   born_date  born_city       born_region  \
# 1897         1907   Keith Hanlon  1966-09-01        NaN               NaN
# 3505         3517  Keith Wallace  1961-03-29    Preston           England
# 6228         6255  Keith Hartley  1940-10-15  Vancouver  British Columbia
# 8898         8946    Keith Mwila  1966-01-01        NaN               NaN
# 12053       12118   Keith Hervey  1898-11-03     Fulham           England
#
#       born_country            NOC  height_cm  weight_kg   died_date
# 1897           NaN        Ireland        NaN        NaN         NaN
# 3505           GBR  Great Britain      165.0       51.0  1999-12-31
# 6228           CAN         Canada      200.0       85.0         NaN
# 8898           NaN         Zambia        NaN        NaN  1993-01-09
# 12053          GBR  Great Britain        NaN        NaN  1973-02-22

# %%
bios[bios["name"].str.contains("Keith|Elizabeth")].head()
# Out:
#       athlete_id              name   born_date  born_city       born_region  \
# 1897        1907      Keith Hanlon  1966-09-01        NaN               NaN
# 2796        2808  Elizabeth Popper  1962-08-30        NaN               NaN
# 3505        3517     Keith Wallace  1961-03-29    Preston           England
# 6228        6255     Keith Hartley  1940-10-15  Vancouver  British Columbia
# 8898        8946       Keith Mwila  1966-01-01        NaN               NaN
#
#      born_country            NOC  height_cm  weight_kg   died_date
# 1897          NaN        Ireland        NaN        NaN         NaN
# 2796          NaN      Venezuela      160.0       70.0         NaN
# 3505          GBR  Great Britain      165.0       51.0  1999-12-31
# 6228          CAN         Canada      200.0       85.0         NaN
# 8898          NaN         Zambia        NaN        NaN  1993-01-09

# %%
#atheletes whose name starts wiht
bios[bios["name"].str.startswith("X")].head()
# Out:
#       athlete_id              name   born_date    born_city born_region  \
# 83            84       Xinhua Chen  1960-01-30         Fuan      Fujian
# 960          964  Xóchitl Escobedo  1968-09-17  West Covina  California
# 1453        1460           Xu Jian  1970-07-27          NaN         NaN
# 1534        1541      Xavier Camps  1970-08-12    Barcelona   Barcelona
# 1536        1543      Xavier Civit  1973-05-17    Barcelona   Barcelona
#
#      born_country                         NOC  height_cm  weight_kg died_date
# 83            CHN               Great Britain      175.0       71.0       NaN
# 960           USA                      Mexico      170.0       60.0       NaN
# 1453          NaN  People's Republic of China      178.0       74.0       NaN
# 1534          ESP                       Spain      180.0       77.0       NaN
# 1536          ESP                       Spain      185.0       78.0       NaN

# %%
# Out:
#         athlete_id               name   born_date         born_city  \
# 54              55      Monique Javer  1967-07-22        Burlingame
# 960            964   Xóchitl Escobedo  1968-09-17       West Covina
# 961            965  Angélica Gavaldón  1973-10-03         El Centro
# 1231          1238     Bert Schneider  1897-07-01         Cleveland
# 1345          1352         Laura Berg  1975-01-06  Santa Fe Springs
# ...            ...                ...         ...               ...
# 145445      149168     Kristen Santos  1994-11-02         Fairfield
# 145446      149169   Corinne Stoddard  2001-08-15           Seattle
# 145454      149180      Anna Hoffmann  2000-03-28           Madison
# 145457      149183     Alix Wilkinson  2000-08-02     Mammoth Lakes
# 145468      149195  Justin Abdelkader  1987-02-25          Muskegon
#
#         born_region born_country            NOC  height_cm  weight_kg  \
# 54       California          USA  Great Britain      177.0       64.0
# ...

# %%
bios[bios["name"].str.endswith("A")].head()
# Out:
#         athlete_id           name   born_date born_city born_region  \
# 5485          5506  Seong Jeong-A  1965-12-25       NaN         NaN
# 42816        43141  Gang Myeong-A  1972-03-30       NaN         NaN
# 42821        43146   Gong Hyeon-A  1972-05-03       NaN         NaN
# 42830        43155   Park Jeong-A  1963-04-20       NaN         NaN
# 106128      107215  Park Gyeong-A  1986-07-21       NaN         NaN
#
#        born_country                NOC  height_cm  weight_kg died_date
# 5485            NaN  Republic of Korea      184.0       70.0       NaN
# 42816           NaN  Republic of Korea        NaN        NaN       NaN
# 42821           NaN  Republic of Korea        NaN        NaN       NaN
# 42830           NaN  Republic of Korea      158.0       50.0       NaN
# 106128          NaN  Republic of Korea      154.0       49.0       NaN
